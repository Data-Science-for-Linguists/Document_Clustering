# %%
import wikipedia
import requests
from bs4 import BeautifulSoup
from gensim.summarization import keywords
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Getting Data
# For this project, all data will be found on publicly available web pages. I'll be using the `requests` and `bs4` modules to acquire data.
#
# My goal is to make this project generalizable and able to work with any list of webpages/URLs. Because of this, I'm focusing on understanding how to work with a small dataset of a few wiki pages for now.
#
# Eventually, I will separate the scraping portion into a script and create a `data/` directory, but that isn't necessary for now.
#
# ### Sharing Data
# Because all of the data I'm using is publicly available on the internet, everyone will have access to all of my data. It will all be either scraped data or built-in corpora (like `gensim.corpora.wikicorpus`). The `data/` directory will probably remain local and gitignored, but I will include a script that can be run to generate everything in `data/`.

# %%
# this can get the data we need
def _get_with_requests(link): 
    import lxml
    req = requests.get(link).text
    soup = BeautifulSoup(req, "html.parser")
    # remove javascript/css 
    [s.decompose() for s in soup.findAll(['script', 'style'])] 
    
    return soup.text

def get_topics(content):
    '''
    takes string of content and returns list of keywords
    '''
    # definitely need to look into more interesting data to rank keywords
    # what exactly does words do... https://radimrehurek.com/gensim/summarization/keywords.html
    return keywords(content, words=20, lemmatize=True).split('\n')

# %%
'''
Pretend we have a list of topics, say Apple, Orange, Yankees, Red Sox. 
Get data, figure out topics, and group.
'''
# for wikipedia pages, use wikipedia api to guarantee nice data
pages = ['Apple', 'Orange_(fruit)', 'Grapefruit', 'Yankees', 'Red Sox', 'Baseball', 'Tree']
pages_content = {page:wikipedia.page(page).content for page in pages}

# %%
# Extract topics from each page
# Topics will be used for section naming, not for grouping. Grouping w/ paragraph2vec?
page_topics = {page:get_topics(content) for page, content in pages_content.items()}

# %% [markdown]
# ### Stats
# This project is designed to be generic and should work for any list of URLs (with varying success, of course).
# This section prints some stats and visualizes the topics.

# %%
print('total pages:', len(pages))
topic_pages = {}
for page, topics in page_topics.items():
    print('page: ', page)
    print('\ttopics:', topics)
    for topic in topics:
        if topic not in topic_pages:
            topic_pages[topic] = [page]
        else:
            topic_pages[topic].append(page)
for topic, pages in topic_pages.items():
    print('\ntopics:', topic)
    print('\tpages:', pages)
# Out:
# total pages: 7
# page:  Red Sox
# 	topics: ['sox', 'boston', 'game', 'teams', 'league', 'season', 'reds', 'players', 'pitcher', 'management', 'new', 'series', 'yankee', 'records', 'pitching', 'clubs', 'include', 'sports', 'outfield', 'year']
# page:  Apple
# 	topics: ['apple', 'fruits', 'cultivars', 'trees', 'including', 'malus', 'davidson', 'disease', 'year', 'organic', 'generic', 'groups', 'pollinators', 'sweet', 'producing', 'likely', 'goddess', 'day', 'high', 'storage']
# page:  Baseball
# 	topics: ['baseball', 'games', 'league', 'players', 'teams', 'isbn', 'balle', 'plays', 'fielding', 'sports', 'batted', 'professionals', 'pitcher', 'pitched', 'american', 'news', 'statistical', 'major', 'bases', 'national']
# page:  Yankees
# 	topics: ['yankees', 'teamed', 'season', 'game', 'new', 'pitcher', 'league', 'baseball', 'year', 'series', 'winning', 'playing', 'records', 'management', 'sports', 'home', 'player', 'hits', 'second', 'steinbrenner']
# page:  Tree
# 	topics: ['tree', 'planting', 'root', 'growth', 'water', 'wood', 'leaved', 'forest', 'include', 'like', 'grow', 'cells', 'contain', 'trunk', 'formed', 'species', 'known', 'seeds', 'produce']
# page:  Grapefruit
# 	topics: ['grapefruit', 'hybrids', 'citrus', 'drug', 'sweets', 'red', 'varieties', 'fruit', 'pummelo', 'color', 'orange', 'origin', 'commercial', 'probably', 'white', 'tangerine', 'effects', 'pink', 'care']
# page:  Orange_(fruit)
# 	topics: ['orange', 'grown', 'fruits', 'citrus', 'tree', 'variety', 'navels', 'florida', 'juice', 'called', 'color', 'produce', 'green', 'harvesters', 'generations', 'states', 'africa', 'include', 'originally', 'area']
#
# topics: day
# 	pages: ['Apple']
#
# topics: africa
# 	pages: ['Orange_(fruit)']
#
# topics: boston
# 	pages: ['Red Sox']
#
# topics: league
# 	pages: ['Red Sox', 'Baseball', 'Yankees']
#
# topics: water
# 	pages: ['Tree']
#
# topics: orange
# 	pages: ['Grapefruit', 'Orange_(fruit)']
#
# topics: likely
# 	pages: ['Apple']
#
# topics: teams
# 	pages: ['Red Sox', 'Baseball']
#
# topics: care
# 	pages: ['Grapefruit']
#
# topics: generations
# 	pages: ['Orange_(fruit)']
#
# topics: high
# 	pages: ['Apple']
#
# topics: color
# 	pages: ['Grapefruit', 'Orange_(fruit)']
#
# topics: white
# 	pages: ['Grapefruit']
#
# topics: generic
# 	pages: ['Apple']
#
# topics: navels
# 	pages: ['Orange_(fruit)']
#
# topics: hits
# 	pages: ['Yankees']
#
# topics: disease
# 	pages: ['Apple']
#
# topics: variety
# 	pages: ['Orange_(fruit)']
#
# topics: baseball
# 	pages: ['Baseball', 'Yankees']
#
# topics: seeds
# 	pages: ['Tree']
#
# topics: outfield
# 	pages: ['Red Sox']
#
# topics: pollinators
# 	pages: ['Apple']
#
# topics: planting
# 	pages: ['Tree']
#
# topics: grow
# 	pages: ['Tree']
#
# topics: sweets
# 	pages: ['Grapefruit']
#
# topics: yankee
# 	pages: ['Red Sox']
#
# topics: management
# 	pages: ['Red Sox', 'Yankees']
#
# topics: groups
# 	pages: ['Apple']
#
# topics: area
# 	pages: ['Orange_(fruit)']
#
# topics: varieties
# 	pages: ['Grapefruit']
#
# topics: fielding
# 	pages: ['Baseball']
#
# topics: pitched
# 	pages: ['Baseball']
#
# topics: leaved
# 	pages: ['Tree']
#
# topics: year
# 	pages: ['Red Sox', 'Apple', 'Yankees']
#
# topics: drug
# 	pages: ['Grapefruit']
#
# topics: hybrids
# 	pages: ['Grapefruit']
#
# topics: florida
# 	pages: ['Orange_(fruit)']
#
# topics: season
# 	pages: ['Red Sox', 'Yankees']
#
# topics: storage
# 	pages: ['Apple']
#
# topics: games
# 	pages: ['Baseball']
#
# topics: tangerine
# 	pages: ['Grapefruit']
#
# topics: goddess
# 	pages: ['Apple']
#
# topics: fruit
# 	pages: ['Grapefruit']
#
# topics: apple
# 	pages: ['Apple']
#
# topics: cultivars
# 	pages: ['Apple']
#
# topics: root
# 	pages: ['Tree']
#
# topics: reds
# 	pages: ['Red Sox']
#
# topics: effects
# 	pages: ['Grapefruit']
#
# topics: states
# 	pages: ['Orange_(fruit)']
#
# topics: originally
# 	pages: ['Orange_(fruit)']
#
# topics: produce
# 	pages: ['Tree', 'Orange_(fruit)']
#
# topics: pummelo
# 	pages: ['Grapefruit']
#
# topics: wood
# 	pages: ['Tree']
#
# topics: fruits
# 	pages: ['Apple', 'Orange_(fruit)']
#
# topics: american
# 	pages: ['Baseball']
#
# topics: player
# 	pages: ['Yankees']
#
# topics: davidson
# 	pages: ['Apple']
#
# topics: juice
# 	pages: ['Orange_(fruit)']
#
# topics: forest
# 	pages: ['Tree']
#
# topics: batted
# 	pages: ['Baseball']
#
# topics: isbn
# 	pages: ['Baseball']
#
# topics: species
# 	pages: ['Tree']
#
# topics: contain
# 	pages: ['Tree']
#
# topics: statistical
# 	pages: ['Baseball']
#
# topics: sports
# 	pages: ['Red Sox', 'Baseball', 'Yankees']
#
# topics: growth
# 	pages: ['Tree']
#
# topics: series
# 	pages: ['Red Sox', 'Yankees']
#
# topics: commercial
# 	pages: ['Grapefruit']
#
# topics: records
# 	pages: ['Red Sox', 'Yankees']
#
# topics: like
# 	pages: ['Tree']
#
# topics: grown
# 	pages: ['Orange_(fruit)']
#
# topics: yankees
# 	pages: ['Yankees']
#
# topics: national
# 	pages: ['Baseball']
#
# topics: grapefruit
# 	pages: ['Grapefruit']
#
# topics: playing
# 	pages: ['Yankees']
#
# topics: teamed
# 	pages: ['Yankees']
#
# topics: red
# 	pages: ['Grapefruit']
#
# topics: citrus
# 	pages: ['Grapefruit', 'Orange_(fruit)']
#
# topics: organic
# 	pages: ['Apple']
#
# topics: steinbrenner
# 	pages: ['Yankees']
#
# topics: known
# 	pages: ['Tree']
#
# topics: pitcher
# 	pages: ['Red Sox', 'Baseball', 'Yankees']
#
# topics: winning
# 	pages: ['Yankees']
#
# topics: origin
# 	pages: ['Grapefruit']
#
# topics: producing
# 	pages: ['Apple']
#
# topics: sweet
# 	pages: ['Apple']
#
# topics: balle
# 	pages: ['Baseball']
#
# topics: pitching
# 	pages: ['Red Sox']
#
# topics: green
# 	pages: ['Orange_(fruit)']
#
# topics: harvesters
# 	pages: ['Orange_(fruit)']
#
# topics: major
# 	pages: ['Baseball']
#
# topics: new
# 	pages: ['Red Sox', 'Yankees']
#
# topics: professionals
# 	pages: ['Baseball']
#
# topics: malus
# 	pages: ['Apple']
#
# topics: game
# 	pages: ['Red Sox', 'Yankees']
#
# topics: probably
# 	pages: ['Grapefruit']
#
# topics: trees
# 	pages: ['Apple']
#
# topics: home
# 	pages: ['Yankees']
#
# topics: bases
# 	pages: ['Baseball']
#
# topics: formed
# 	pages: ['Tree']
#
# topics: sox
# 	pages: ['Red Sox']
#
# topics: include
# 	pages: ['Red Sox', 'Tree', 'Orange_(fruit)']
#
# topics: second
# 	pages: ['Yankees']
#
# topics: players
# 	pages: ['Red Sox', 'Baseball']
#
# topics: trunk
# 	pages: ['Tree']
#
# topics: news
# 	pages: ['Baseball']
#
# topics: clubs
# 	pages: ['Red Sox']
#
# topics: tree
# 	pages: ['Tree', 'Orange_(fruit)']
#
# topics: plays
# 	pages: ['Baseball']
#
# topics: called
# 	pages: ['Orange_(fruit)']
#
# topics: pink
# 	pages: ['Grapefruit']
#
# topics: cells
# 	pages: ['Tree']
#
# topics: including
# 	pages: ['Apple']

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
sns.set_style('dark')

topic_list = []
num_pages = []
for topic, pages in topic_pages.items():
    if len(pages) > 1:
        topic_list.append(topic)
        num_pages.append(len(pages))
sorted_pages = sorted(zip(num_pages, topic_list))
num_pages = [x[0] for x in sorted_pages]
topic_list = [x[1] for x in sorted_pages]
plt.barh(np.arange(len(topic_list)), num_pages)
plt.yticks(np.arange(len(topic_list)),topic_list)
plt.show()

# %%
# Are apple/grapefruit/lemon all under fruit?
print(topic_pages['fruit'])
# Out:
# ['Grapefruit']

# %%
# nope.
print(topic_pages['fruits'])
# looks like the lemmatize param in gensim keywords() does some weird stuff.
# Out:
# ['Apple', 'Orange_(fruit)']

# %%
print(topic_pages['baseball'])
# Out:
# ['Baseball', 'Yankees']

# %% [markdown]
# And apparently Red Sox doesn't even have the keyword baseball.
